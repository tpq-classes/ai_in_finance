# %% [markdown]
# <img src='http://hilpisch.com/taim_logo.png' width="350px" align="right">

# %% [markdown]
# # AI-First Finance
#
# **OLS Regression as the Benchmark**

# %% [markdown]
# Dr Yves J Hilpisch | The AI Machine
#
# http://aimachine.io | http://twitter.com/dyjh

# %% [markdown]
# ## Imports

# %%
# !git clone https://github.com/tpq-classes/ai_in_finance.git
import sys
sys.path.append('ai_in_finance')
# Out:
# fatal: destination path 'ai_in_finance' already exists and is not an empty directory.

# %%
# !pip install eikon
# Out:
# Requirement already satisfied: eikon in /usr/local/lib/python3.12/dist-packages (1.1.18)
# Requirement already satisfied: httpx>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from eikon) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from eikon) (1.6.0)
# Requirement already satisfied: datetime in /usr/local/lib/python3.12/dist-packages (from eikon) (6.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from eikon) (2.2.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from eikon) (2.0.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from eikon) (1.4.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from eikon) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.54.0 in /usr/local/lib/python3.12/dist-packages (from eikon) (1.9.0)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.12/dist-packages (from eikon) (2.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from eikon) (2026.5.20)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.12/dist-packages (from eikon) (3.0.4)
# Requirement already satisfied: h2==4.* in /usr/local/lib/python3.12/dist-packages (from eikon) (4.3.0)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.12/dist-packages (from eikon) (2.10)
# Requirement already satisfied: rfc3986==1.* in /usr/local/lib/python3.12/dist-packages (from eikon) (1.5.0)
# Requirement already satisfied: requests==2.* in /usr/local/lib/python3.12/dist-packages (from eikon) (2.32.4)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2==4.*->eikon) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2==4.*->eikon) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.*->eikon) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.*->eikon) (2.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.18.0->eikon) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.18.0->eikon) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.18.0->eikon) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->eikon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->eikon) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->eikon) (1.17.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.12/dist-packages (from datetime->eikon) (8.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from deprecation->eikon) (26.2)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.18.0->eikon) (4.15.0)

# %%
from fix_cufflink import *
cf_colors.to_rgba = fixed_to_rgba
cf_plotlytools.to_rgba = fixed_to_rgba

# %%
import math
import eikon as ek
import numpy as np
import pandas as pd
from pylab import plt
plt.style.use('seaborn-v0_8')
import cufflinks
cufflinks.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## OLS Regression

# %% [markdown]
# ### Simple Regression

# %%
x = np.linspace(0, 5, 100)
y = 2 + 0.5 * x + np.random.standard_normal(len(x)) * 0.15

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'ro');

# %%
np.cov(x, y)
# Out:
# array([[2.14688977, 1.05756785],
#        [1.05756785, 0.54360103]])

# %%
cov = np.cov(x, y)[0, 1]

# %%
beta = cov / x.var()

# %%
alpha = y.mean() - beta * x.mean()

# %%
alpha, beta
# Out:
# (np.float64(1.9979119814160307), np.float64(0.49758043862783524))

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, alpha + beta * x, lw=2.0)
plt.plot(x, y, 'ro');

# %%
r = alpha + beta * x - y

# %% [markdown]
# Check for assumptions:
# * **linearity**: given
# * **independence**: given
# * **zero mean**: mean zero given (see below)
# * **no correlation**: correlation of zero (see below)
# * **homoscedasticity**: given (see below)
# * **no autocorrelation**: given (see below)
#
# See also [Linear Regression Assumptions](https://medium.com/datadriveninvestor/linear-regression-assumptions-f2252b8e2912) or [Ordinary Least Squares](https://en.wikipedia.org/wiki/Ordinary_least_squares).

# %%
r.mean()
# Out:
# np.float64(2.5313084961453567e-16)

# %%
np.corrcoef(r, x)
# Out:
# array([[1.        , 0.04839917],
#        [0.04839917, 1.        ]])

# %%
from scipy.stats import bartlett

# %%
split = int(len(x) / 2)

# %%
bartlett(r[:split], r[split:])
# Out:
# BartlettResult(statistic=np.float64(1.075855582005727), pvalue=np.float64(0.2996265441117482))

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.graphics.tsaplots import plot_acf

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plot_acf(r, ax=ax);

# %% [markdown]
# ### Monomial Regression

# %%
x = np.linspace(0, 5, 100)
y = 2 - 0.5 * x ** 2 + 0.1 * x ** 3 + np.random.standard_normal(len(x)) * 0.15

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'ro');

# %%
reg = np.polyfit(x, y, deg=3)
reg
# Out:
# array([ 0.09714773, -0.48343941, -0.01466825,  1.98245967])

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, np.polyval(reg, x), lw=2.0)
plt.plot(x, y, 'ro');

# %%
r = np.polyval(reg, x) - y

# %% [markdown]
# Check for assumptions:
# * **linearity**: given
# * **independence**: given
# * **zero mean**: given
# * **no correlation**: given
# * **homoscedasticity**: given
# * **no autocorrelation**: given

# %%
r.mean()
# Out:
# np.float64(1.887379141862766e-16)

# %%
np.corrcoef(r, x)
# Out:
# array([[1.00000000e+00, 5.06524441e-15],
#        [5.06524441e-15, 1.00000000e+00]])

# %%
split = int(len(x) / 2)

# %%
bartlett(r[:split], r[split:])
# Out:
# BartlettResult(statistic=np.float64(0.2832519107673589), pvalue=np.float64(0.5945776777131969))

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plot_acf(r, ax=ax);

# %% [markdown]
# ### Multivariate Regression

# %%
x1 = np.random.random(200) * 5
x2 = np.random.random(200) * 5
y = 2 - 0.5 * x1 ** 2 + 0.1 * x2 ** 3 + np.random.standard_normal(len(x1)) * 0.15

# %%
df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y, 'text': '', 'categories': ''})

# %%
df.iplot(kind='scatter3d', x='x1', y='x2', z='y',
         text='text', categories='categories', size=4)
# Out:
# <div>                            <div id="a6f70a6b-4102-4792-8940-e3b6accf02ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a6f70a6b-4102-4792-8940-e3b6accf02ae")) {                    Plotly.newPlot(                        "a6f70a6b-4102-4792-8940-e3b6accf02ae",                        [{"marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"width":1.3},"opacity":0.8,"size":4,"symbol":"circle"},"mode":"markers","name":"","text":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","
# %% [markdown]
# Check for assumptions:
# * **linearity**: given
# * **independence**: given (see corr x1 & x2)
# * **zero mean**: non-zero mean
# * **no correlation**: not given
# * **homoscedasticity**: given
# * **no autocorrelation**: given

# %%
df.corr(numeric_only=True)
# Out:
#           x1        x2         y         r
# x1  1.000000  0.012565 -0.708181  0.274740
# x2  0.012565  1.000000  0.603650  0.270178
# y  -0.708181  0.603650  1.000000 -0.355409
# r   0.274740  0.270178 -0.355409  1.000000

# %%
r.mean()
# Out:
# np.float64(-0.29544589115775866)

# %%
split = int(len(x) / 2)

# %%
# help(bartlett)

# %%
bartlett(r[:split], r[split:])
# Out:
# BartlettResult(statistic=np.float64(0.00660983321794038), pvalue=np.float64(0.9352026735382232))

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plot_acf(r, ax=ax);

# %% [markdown]
# ## Fast and Scalable

# %%
# %%time
N = 10000000
x1 = np.random.random(N) * 5
x2 = np.random.random(N) * 5
x3 = np.random.random(N) * 5
B = np.array((x1, x2, x3)).T
y = 2 + 5 * x1 - 0.5 * x2 ** 2 + 0.1 * x3 ** 3 + np.random.standard_normal(len(x1)) * 0.15
# Out:
# CPU times: user 1.45 s, sys: 246 ms, total: 1.7 s
# Wall time: 2.64 s

# %%
x1.nbytes * 4 / 1e6  # MB
# Out:
# 320.0

# %%
# %time np.linalg.lstsq(B, y, rcond=-1)[0]
# Out:
# CPU times: user 773 ms, sys: 211 ms, total: 984 ms
# Wall time: 1.42 s
# array([ 5.18985237, -2.30931149,  2.43979605])

# %% [markdown]
# ## Linear Regression with Scikit-Learn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import tensorflow as tf

# %%
x = np.linspace(0, 5, 50)
y = 2 - 0.5 * x ** 2 + 0.1 * x ** 3 + np.random.standard_normal(len(x)) * 0.1

# %%
model = LinearRegression()

# %%
model.fit(np.atleast_2d(x).T, y)
# Out:
# LinearRegression()

# %%
pred = model.predict(np.atleast_2d(x).T)
pred[:5]
# Out:
# array([1.56219554, 1.53913308, 1.51607062, 1.49300816, 1.4699457 ])

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, pred)
plt.plot(x, y, 'ro');

# %%
r2_score(y, [y.mean()] * len(y))
# Out:
# 0.0

# %%
r2_score(y, pred)
# Out:
# 0.2626743770484987

# %% [markdown]
# ## Monomial Regression with Scikit-Learn

# %% [markdown]
# See VanderPlas: Python Data Science Handbook (O'Reilly).

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
def PolynomialRegression(degree=2, **kwargs):
    return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

# %%
x = np.atleast_2d(x).T

# %%
x_ = np.atleast_2d(np.linspace(x.min(), x.max(), 50)).T

# %%
res = {}
for deg in [1, 3, 5]:
    model = PolynomialRegression(deg)
    model.fit(x, y)
    res[deg] = model.predict(x_)

# %%
plt.figure(figsize=(10, 6))
for key in res:
    plt.plot(x_, res[key], label=f'degree={key}')
plt.plot(x, y, 'ro')
plt.legend();

# %%
for deg in [1, 2, 3, 4, 5]:
    y_ = PolynomialRegression(deg).fit(x.reshape(-1, 1), y).predict(x.reshape(-1, 1))
    R2 = r2_score(y, y_)
    print(f'degree={deg} | R2={R2}')
# Out:
# degree=1 | R2=0.2626743770484987
# degree=2 | R2=0.8393926748871391
# degree=3 | R2=0.9757842769756815
# degree=4 | R2=0.9772865576683586
# degree=5 | R2=0.9772867372426486

# %% [markdown]
# ## Model Validation

# %% [markdown]
# ### Simple Split

# %%
split = int(len(x) * 0.6)

# %%
model = PolynomialRegression(2)

# %%
model.fit(x[:split], y[:split])
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
pred = model.predict(x)

# %%
plt.figure(figsize=(10, 6))
plt.plot(x[:split], pred[:split], 'b--')
plt.plot(x[split:], pred[split:], 'y--')
plt.plot(x, y, 'ro');

# %% [markdown]
# ### Random Split

# %%
i = np.arange(len(x))
np.random.shuffle(i)

# %%
model.fit(x[i[:split]], y[i[:split]])
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %% [raw]
# pred = model.predict(x)

# %%
pred = model.predict(x)

# %%
plt.figure(figsize=(10, 6))
plt.plot(x[:split], pred[:split], 'b--')
plt.plot(x[split:], pred[split:], 'y--')
plt.plot(x, y, 'ro');

# %% [markdown]
# ## Validation Curves

# %%
from sklearn.model_selection import validation_curve

# %%
degrees = np.arange(1, 6)

# %%
# validation_curve?

# %%
train_score, val_score = validation_curve(PolynomialRegression(), X=x, y=y,
                                         param_name='polynomialfeatures__degree',
                                         param_range=degrees, cv=5)

# %%
plt.figure(figsize=(10, 6))
plt.plot(degrees, np.median(train_score, axis=1), label='training score')
plt.plot(degrees, np.median(val_score, axis=1), label='validation score')
plt.legend();

# %% [markdown]
# ## Random Walks

# %% [markdown]
# Eugene F. Fama (1965): “Random Walks in Stock Market Prices”:
#
# > “For many years, economists, statisticians, and teachers of finance have been interested in developing and testing models of stock price behavior. One important model that has evolved from this research is the theory of random walks. This theory casts serious doubt on many other methods for describing and predicting stock price behavior—methods that have considerable popularity outside the academic world. For example, we shall see later that, if the random-walk theory is an accurate description of reality, then the various “technical” or “chartist” procedures for predicting stock prices are completely without value.”

# %% [markdown]
# Michael Jensen (1978): “Some Anomalous Evidence Regarding Market Efficiency”:
#
# >“A market is efficient with respect to an information set S if it is impossible to make economic profits by trading on the basis of information set S.”

# %% [markdown]
# If a stock price follows a (simple) random walk (no drift & normally distributed returns), then it rises and falls with the same probability of 50% (“toss of a coin”).
#
# **In such a case, the best predictor of tomorrow’s stock price — in a least-squares sense — is today’s stock price.**

# %% [markdown]
# ### Retrieving Cross-Asset Data

# %%
url = 'http://hilpisch.com/tr_eikon_eod_data.csv'

# %%
data = pd.read_csv(url, index_col=0, parse_dates=True).dropna()

# %%
data.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
# 2010-01-08  30.282827  30.660   20.83  133.52  174.31  114.57  1144.98  18.13
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82
# 2010-01-08  1.4412  1136.10  49.84  111.37

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2138 entries, 2010-01-04 to 2018-06-29
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2138 non-null   float64
#  1   MSFT.O  2138 non-null   float64
#  2   INTC.O  2138 non-null   float64
#  3   AMZN.O  2138 non-null   float64
#  4   GS.N    2138 non-null   float64
#  5   SPY     2138 non-null   float64
#  6   .SPX    2138 non-null   float64
#  7   .VIX    2138 non-null   float64
#  8   EUR=    2138 non-null   float64
#  9   XAU=    2138 non-null   float64
#  10  GDX     2138 non-null   float64
#  11  GLD     2138 non-null   float64
# dtypes: float64(12)
# memory usage: 217.1 KB

# %% [markdown]
# ### Calculating the Log Returns

# %%
rets = np.log(data / data.shift(1))

# %%
rets.head()
# Out:
#               AAPL.O    MSFT.O    INTC.O    AMZN.O      GS.N       SPY  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.001727  0.000323 -0.000479  0.005883  0.017525  0.002644
# 2010-01-06 -0.016034 -0.006156 -0.003360 -0.018282 -0.010731  0.000704
# 2010-01-07 -0.001850 -0.010389 -0.009662 -0.017160  0.019379  0.004212
# 2010-01-08  0.006626  0.006807  0.011103  0.026717 -0.019093  0.003322
#
#                 .SPX      .VIX      EUR=      XAU=       GDX       GLD
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.003111 -0.035038 -0.002988 -0.001206  0.009595 -0.000911
# 2010-01-06  0.000545 -0.009868  0.003058  0.017589  0.023999  0.016365
# 2010-01-07  0.003993 -0.005233 -0.006544 -0.005814 -0.004876 -0.006207
# 2010-01-08  0.002878 -0.050024  0.006544  0.003704  0.014959  0.004951

# %% [markdown]
# ### Plotting the Data

# %%
data.normalize().iplot(kind='lines')
# Out:
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
# <div>                            <div id="51bcddf0-5126-4e15-9087-20f8e068c697" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("51bcddf0-5126-4e15-9087-20f8e068c697")) {                    Plotly.newPlot(                        "51bcddf0-5126-4e15-9087-20f8e068c697",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"AAPL.O","text":"","x":["2010-01-04","2010-01-05","2010-01-06","2010-01-07","2010-01-08","2010-01-11","2010-01-12","2010-01-13","2010-01-14","2010-01-15","2010-01-19","2010-01-20","2010-01-21","2010-01-22","2010-01-25","2010-01-26","2010-01-27","2010-01-28","2010-01-29","2010-02-01","2010-02-02","2010-02-03","2010-02-04","2010-02-05","2010-02-08","2010-02-09","2010-02-10","2010-02-11","2010-02-12","2010-02-16","2010-02-17","2010-02-18","2010-02-19","2010-02-22","2010-02-23","2010-02-24","2010-02-25","2010-02-26","2010-03-01","2010-03-02","2010-03-03","2010-03-04","2010-03-05","2010-03-08","2010-03-09","2010-03-10","2010-03-11","2010-03-12","2010-03-15","2010-03-16","2010-03-17","2010-
0.3027272899802979,0.2769546931547262],[0.03267913862657903,-0.0098389715562129,-0.001005573611509085,-0.030366280096309577,-0.062358920018320614,-0.00019916939656191182,0.003926536033607987,-0.000028685412113551554,0.2790205693482338,1.0,0.7479111073886489,0.9884706948597813],[0.14958093127815145,0.12697049650417125,0.13566726166431073,0.08304132564105078,0.08118512440952878,0.20589998441773485,0.20836353286792073,-0.16621844182282247,0.3027272899802979,0.7479111073886489,1.0,0.7564057987718827],[0.036999931071909554,-0.009498827991721014,-0.00008550890184003906,-0.029168829907048933,-0.0589934346786559,0.0025958746441175876,0.006447276556043333,0.0009943075281195364,0.2769546931547262,0.9884706948597813,0.7564057987718827,1.0]],"zmax":1.0,"zmin":-0.8043822018632394,"type":"heatmap"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet ...

# %% [markdown]
# ### Preparing Lagged Data

# %%
def add_lags(data, ric, lags):
    cols = []
    df = pd.DataFrame(data[ric])
    for lag in range(1, lags + 1):
        col = 'lag_{}'.format(lag)  # defines the column name
        df[col] = df[ric].shift(lag)  # creates the lagged data column
        cols.append(col)  # stores the column name
    df.dropna(inplace=True)  # gets rid of incomplete data rows
    return df, cols

# %%
lags = 7  # seven historical lags

# %%
dfs = {}
for sym in data.columns:
    df, cols = add_lags(data, sym, lags)
    dfs[sym] = df

# %%
cols  # the column names for the lags
# Out:
# ['lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7']

# %%
dfs.keys()  # the keys of the dictonary
# Out:
# dict_keys(['AAPL.O', 'MSFT.O', 'INTC.O', 'AMZN.O', 'GS.N', 'SPY', '.SPX', '.VIX', 'EUR=', 'XAU=', 'GDX', 'GLD'])

# %%
dfs['AAPL.O'].head(7)
# Out:
#                AAPL.O      lag_1      lag_2      lag_3      lag_4      lag_5  \
# Date
# 2010-01-13  30.092827  29.674256  30.015684  30.282827  30.082827  30.138541
# 2010-01-14  29.918542  30.092827  29.674256  30.015684  30.282827  30.082827
# 2010-01-15  29.418542  29.918542  30.092827  29.674256  30.015684  30.282827
# 2010-01-19  30.719969  29.418542  29.918542  30.092827  29.674256  30.015684
# 2010-01-20  30.246398  30.719969  29.418542  29.918542  30.092827  29.674256
# 2010-01-21  29.724542  30.246398  30.719969  29.418542  29.918542  30.092827
# 2010-01-22  28.249972  29.724542  30.246398  30.719969  29.418542  29.918542
#
#                 lag_6      lag_7
# Date
# 2010-01-13  30.625684  30.572827
# 2010-01-14  30.138541  30.625684
# 2010-01-15  30.082827  30.138541
# 2010-01-19  30.282827  30.082827
# 2010-01-20  30.015684  30.282827
# 2010-01-21  29.674256  30.015684
# 2010-01-22  30.092827  29.674256

# %% [markdown]
# ### Implementing OLS Regression

# %%
regs = {}
for sym in data.columns:
    df = dfs[sym]  # getting data for the RIC
    reg = np.linalg.lstsq(df[cols], df[sym], rcond=-1)[0]  # the OLS regression
    regs[sym] = reg  # storing the results

# %%
for sym in data.columns:
    print('{:10} | {}'.format(sym, regs[sym].round(4)))
# Out:
# AAPL.O     | [ 1.0399 -0.0572  0.0116  0.053  -0.0704  0.0178  0.006 ]
# MSFT.O     | [ 0.9161  0.0246  0.0922 -0.0452 -0.071   0.0637  0.0206]
# INTC.O     | [ 0.94    0.0472  0.0783 -0.0727 -0.0016 -0.0177  0.0269]
# AMZN.O     | [ 0.9925  0.0048 -0.0577  0.0187  0.0503  0.0258 -0.0325]
# GS.N       | [ 0.9576  0.044   0.0069 -0.0043 -0.0485  0.0708 -0.0264]
# SPY        | [ 0.9621  0.0045  0.0358 -0.0169 -0.046   0.0518  0.0091]
# .SPX       | [ 0.9593  0.0105  0.0316 -0.0177 -0.0497  0.0593  0.007 ]
# .VIX       | [ 0.8815  0.0563 -0.0295  0.0304 -0.0331  0.07    0.0216]
# EUR=       | [ 0.9886  0.0207 -0.0506  0.058  -0.0228  0.0133 -0.0073]
# XAU=       | [ 0.9895  0.0017  0.0194 -0.0212  0.0084  0.0132 -0.0111]
# GDX        | [ 0.9768  0.0051  0.0016  0.0185 -0.0296  0.0339 -0.0069]
# GLD        | [ 0.979   0.021   0.0063 -0.0111 -0.0036  0.017  -0.0087]

# %%
rega = np.stack(list(regs.values()))  # combines the regression results

# %%
rega.mean(axis=0)  # mean values by column
# Out:
# array([ 9.65236834e-01,  1.52641961e-02,  1.21500134e-02, -8.62056807e-04,
#        -2.64641861e-02,  3.49041452e-02, -1.32268020e-04])

# %%
regd = pd.DataFrame(rega, columns=cols, index=data.columns)  # converting the results to DataFrame

# %%
regd
# Out:
#            lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7
# AAPL.O  1.039878 -0.057215  0.011625  0.052956 -0.070424  0.017816  0.005984
# MSFT.O  0.916074  0.024588  0.092184 -0.045194 -0.070999  0.063723  0.020627
# INTC.O  0.940037  0.047160  0.078312 -0.072658 -0.001632 -0.017724  0.026938
# AMZN.O  0.992462  0.004786 -0.057689  0.018676  0.050290  0.025767 -0.032455
# GS.N    0.957610  0.044034  0.006875 -0.004325 -0.048481  0.070784 -0.026441
# SPY     0.962086  0.004546  0.035751 -0.016863 -0.045955  0.051802  0.009074
# .SPX    0.959344  0.010530  0.031568 -0.017666 -0.049670  0.059306  0.007034
# .VIX    0.881489  0.056263 -0.029519  0.030393 -0.033142  0.069953  0.021616
# EUR=    0.988572  0.020702 -0.050574  0.058046 -0.022820  0.013273 -0.007328
# XAU=    0.989468  0.001684  0.019411 -0.021153  0.008389  0.013248 -0.011062
# GDX     0.976816  0.005121  0.001571  0.018505 -0.029558  0.033855 -0.006863
# GLD     0.979005  0.020972  0.006286 -0.011062 -0.003567  0.017048 -0.008710

# %%
regd.iplot(kind='bar')
# Out:
# <div>                            <div id="680ccd4c-80c2-4747-adc6-75efc21305f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("680ccd4c-80c2-4747-adc6-75efc21305f1")) {                    Plotly.newPlot(                        "680ccd4c-80c2-4747-adc6-75efc21305f1",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":
}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker": ...

# %%
regd.mean().iplot(kind='bar')
# Out:
# <div>                            <div id="fd0ce304-74be-4cae-a944-f249174ae7e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("fd0ce304-74be-4cae-a944-f249174ae7e3")) {                    Plotly.newPlot(                        "fd0ce304-74be-4cae-a944-f249174ae7e3",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["lag_1","lag_2","lag_3","lag_4","lag_5","lag_6","lag_7"],"y":[0.9652368335087118,0.015264196082922565,0.012150013444582981,-0.0008620568074227971,-0.026464186084690613,0.034904145221609804,-0.00013226802033248697],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}], ...

# %% [markdown]
# ## Cross Check

# %%
sym = 'AAPL.O'

# %%
reg = regd.loc[sym].values

# %%
y_ = np.dot(dfs[sym][cols], reg)

# %%
r = y_ - dfs[sym][sym]

# %% [markdown]
# Check for assumptions:
# * **linearity**: given
# * **independence**: <b style="color: red;">not at all</b>
# * **zero mean**: somehow
# * **no correlation**: given
# * **homoscedasticity**: **not given**
# * **no autocorrelation**: given
# * **stationarity**: **not given**

# %%
dfs[sym][cols].corr()
# Out:
#           lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7
# lag_1  1.000000  0.999324  0.998597  0.997893  0.997197  0.996437  0.995703
# lag_2  0.999324  1.000000  0.999324  0.998595  0.997892  0.997193  0.996432
# lag_3  0.998597  0.999324  1.000000  0.999323  0.998594  0.997889  0.997190
# lag_4  0.997893  0.998595  0.999323  1.000000  0.999323  0.998593  0.997887
# lag_5  0.997197  0.997892  0.998594  0.999323  1.000000  0.999323  0.998593
# lag_6  0.996437  0.997193  0.997889  0.998593  0.999323  1.000000  0.999322
# lag_7  0.995703  0.996432  0.997190  0.997887  0.998593  0.999322  1.000000

# %%
r.mean()
# Out:
# np.float64(-0.01253520063419023)

# %%
split = int(len(x) / 2)

# %%
np.corrcoef(r, dfs[sym]['lag_3'])
# Out:
# array([[1.        , 0.01956973],
#        [0.01956973, 1.        ]])

# %%
bartlett(r[:split], r[split:])
# Out:
# BartlettResult(statistic=np.float64(19.531869568078985), pvalue=np.float64(9.893525354777573e-06))

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plot_acf(r, ax=ax);

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(dfs[sym][sym])
# Out:
# (np.float64(-0.035708575406915216),
#  np.float64(0.9554774872404644),
#  11,
#  2119,
#  {'1%': np.float64(-3.4334397778912775),
#   '5%': np.float64(-2.8629049396081134),
#   '10%': np.float64(-2.5674966284215643)},
#  np.float64(7649.669468601774))

# %% [markdown]
# ## A Gleam of Hope?

# %% [markdown]
# ### Multi Layer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
model = MLPClassifier(hidden_layer_sizes=(250, 250), max_iter=100)

# %%
sym = 'AAPL.O'

# %% [markdown]
# ### Return Patterns

# %%
rets = np.log(dfs[sym] / dfs[sym].shift(1)).dropna()

# %%
adfuller(rets[sym])
# Out:
# (np.float64(-13.21627699050607),
#  np.float64(1.0229521621761147e-24),
#  12,
#  2117,
#  {'1%': np.float64(-3.433442700457683),
#   '5%': np.float64(-2.8629062300113994),
#   '10%': np.float64(-2.567497315483069)},
#  np.float64(-11471.19510026667))

# %%
rets['d'] = np.sign(rets[sym])

# %%
# rets[cols] = np.sign(rets[cols])

# %%
# rets[cols] -= rets[cols].mean()
# rets[cols] /= rets[cols].std()

# %%
rets.head()
# Out:
#               AAPL.O     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2010-01-14 -0.005808  0.014007 -0.011440 -0.008861  0.006626 -0.001850
# 2010-01-15 -0.016853 -0.005808  0.014007 -0.011440 -0.008861  0.006626
# 2010-01-19  0.043288 -0.016853 -0.005808  0.014007 -0.011440 -0.008861
# 2010-01-20 -0.015536  0.043288 -0.016853 -0.005808  0.014007 -0.011440
# 2010-01-21 -0.017404 -0.015536  0.043288 -0.016853 -0.005808  0.014007
#
#                lag_6     lag_7    d
# Date
# 2010-01-14 -0.016034  0.001727 -1.0
# 2010-01-15 -0.001850 -0.016034 -1.0
# 2010-01-19  0.006626 -0.001850  1.0
# 2010-01-20 -0.008861  0.006626 -1.0
# 2010-01-21 -0.011440 -0.008861 -1.0

# %% [markdown]
# ### Model Fitting & Prediction

# %%
model = model.fit(rets[cols], rets['d'])

# %%
rets['p'] = model.predict(rets[cols])

# %%
accuracy_score(rets['d'], rets['p'])
# Out:
# 0.5220657276995305

# %% [markdown]
# ### Vectorized Backtesting

# %%
(rets['p'].diff() != 0).sum()
# Out:
# np.int64(1)

# %%
rets['strategy'] = rets['p'] * rets[sym]

# %%
rets[[sym, 'strategy']].cumsum().apply(np.exp).iplot()
# Out:
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
# <div>                            <div id="7076ad8c-0bac-4a6e-af5f-ff9d6f88139d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("7076ad8c-0bac-4a6e-af5f-ff9d6f88139d")) {                    Plotly.newPlot(                        "7076ad8c-0bac-4a6e-af5f-ff9d6f88139d",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"AAPL.O","text":"","x":["2010-01-14","2010-01-15","2010-01-19","2010-01-20","2010-01-21","2010-01-22","2010-01-25","2010-01-26","2010-01-27","2010-01-28","2010-01-29","2010-02-01","2010-02-02","2010-02-03","2010-02-04","2010-02-05","2010-02-08","2010-02-09","2010-02-10","2010-02-11","2010-02-12","2010-02-16","2010-02-17","2010-02-18","2010-02-19","2010-02-22","2010-02-23","2010-02-24","2010-02-25","2010-02-26","2010-03-01","2010-03-02","2010-03-03","2010-03-04","2010-03-05","2010-03-08","2010-03-09","2010-03-10","2010-03-11","2010-03-12","2010-03-15","2010-03-16","2010-03-17","2010-03-18","2010-03-19","2010-03-22","2010-03-23","2010-03-24","2010-03-25","2010-03-26","2010-03-29","2010-03-30","2010-03-31","2010-04-01","2010-04-05","2010-04-06","2010-04-07","2010-04-08","2010-04-09","2010-04-12","2010-04